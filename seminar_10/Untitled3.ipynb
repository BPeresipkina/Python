# %% [markdown]
# <a href="https://colab.research.google.com/github/BPeresipkina/Python/blob/main/seminar_10/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# Задача 44

# %%
import random
lst = ['robot'] * 10
lst += ['human'] * 10
random.shuffle(lst)
data = pd.DataFrame({'whoAmI':lst})
data.head()
# Out:
#   whoAmI
# 0  human
# 1  robot
# 2  human
# 3  human
# 4  robot

# %%
data.loc[data['whoAmI']=='robot', 'robot'] = 1
data.loc[data['whoAmI']!='robot', 'robot'] = 0
data.loc[data['whoAmI']=='human', 'human'] = 1
data.loc[data['whoAmI']!='human', 'human'] = 0

# %%
data.head(15)
# Out:
#    whoAmI  robot  human
# 0   human    0.0    1.0
# 1   robot    1.0    0.0
# 2   human    0.0    1.0
# 3   human    0.0    1.0
# 4   robot    1.0    0.0
# 5   robot    1.0    0.0
# 6   robot    1.0    0.0
# 7   robot    1.0    0.0
# 8   human    0.0    1.0
# 9   robot    1.0    0.0
# 10  human    0.0    1.0
# 11  robot    1.0    0.0
# 12  human    0.0    1.0
# 13  human    0.0    1.0
# 14  robot    1.0    0.0
